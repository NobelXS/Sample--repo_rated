# %%
import pandas as pd

df = pd.read_csv('CaseStudyData.csv')
df.head()
# Out:
#    TargetVariable  Variable1  Variable2  Variable3 Variable4 Variable5  \
# 0               1   2.357542       29.0          2    10.50      green
# 1               1   2.000362       50.0          2    10.50      green
# 2               0   2.000029       34.0          3    69.55      green
# 3               1   2.020183       50.0          2    10.50      green
# 4               0   2.952665       45.0          1    35.50       blue
#
#    Variable6  Variable7 Variable8  Variable9
# 0   4.606326          0    square          0
# 1  10.824921          0     round          0
# 2   5.861325          8    square          2
# 3  10.896444          0  triangle          0
# 4   9.159679          0  triangle          0

# %%
from pycaret.classification import *
s = setup(df, target='TargetVariable')
# Out:
# <style type="text/css">
# #T_f6430_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f6430">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6430_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f6430_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6430_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6430_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f6430_row0_col1" class="data row0 col1" >6745</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6430_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f6430_row1_col1" class="data row1 col1" >TargetVariable</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6430_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f6430_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6430_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f6430_row3_col1" class="data row3 col1" >(600, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6430_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f6430_row4_col1" class="data row4 col1" >(600, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6430_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f6430_row5_col1" class="data row5 col1" >(420, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6430_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f6430_row6_col1" class="data row6 col1" >(180, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f6430_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_f6430_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f6430_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_f6430_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f6430_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f6430_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f6430_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f6430_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f6430_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f6430_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f6430_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f6430_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f6430_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f6430_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f6430_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f6430_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f6430_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f6430_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f6430_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_f6430_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f6430_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_f6430_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f6430_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_f6430_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f6430_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_f6430_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f6430_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_f6430_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f6430_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_f6430_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f6430_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f6430_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_f6430_row22_col1" class="data row22 col1" >4a89</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_3ea93 th {
#   text-align: left;
# }
# #T_3ea93_row0_col0, #T_3ea93_row0_col3, #T_3ea93_row1_col0, #T_3ea93_row1_col1, #T_3ea93_row1_col2, #T_3ea93_row1_col3, #T_3ea93_row1_col4, #T_3ea93_row1_col5, #T_3ea93_row1_col6, #T_3ea93_row1_col7, #T_3ea93_row2_col0, #T_3ea93_row2_col1, #T_3ea93_row2_col2, #T_3ea93_row2_col3, #T_3ea93_row2_col4, #T_3ea93_row2_col5, #T_3ea93_row2_col6, #T_3ea93_row2_col7, #T_3ea93_row3_col0, #T_3ea93_row3_col1, #T_3ea93_row3_col2, #T_3ea93_row3_col3, #T_3ea93_row3_col4, #T_3ea93_row3_col5, #T_3ea93_row3_col6, #T_3ea93_row3_col7, #T_3ea93_row4_col0, #T_3ea93_row4_col1, #T_3ea93_row4_col2, #T_3ea93_row4_col3, #T_3ea93_row4_col4, #T_3ea93_row4_col5, #T_3ea93_row4_col6, #T_3ea93_row4_col7, #T_3ea93_row5_col0, #T_3ea93_row5_col1, #T_3ea93_row5_col2, #T_3ea93_row5_col3, #T_3ea93_row5_col4, #T_3ea93_row5_col5, #T_3ea93_row5_col6, #T_3ea93_row5_col7, #T_3ea93_row6_col0, #T_3ea93_row6_col1, #T_3ea93_row6_col2, #T_3ea93_row6_col3, #T_3ea93_row6_col4, #T_3ea93_row6_col5, #T_3ea93_row6_col6, #T_3ea93_row6_col7, #T_3ea93_row7_col0, #T_3ea93_row7_col1, #T_3ea93_row7_col2, #T_3ea93_row7_col4, #T_3ea93_row7_col5, #T_3ea93_row7_col6, #T_3ea93_row7_col7, #T_3ea93_row8_col0, #T_3ea93_row8_col1, #T_3ea93_row8_col2, #T_3ea93_row8_col3, #T_3ea93_row8_col4, #T_3ea93_row8_col5, #T_3ea93_row8_col6, #T_3ea93_row8_col7, #T_3ea93_row9_col0, #T_3ea93_row9_col1, #T_3ea93_row9_col2, #T_3ea93_row9_col3, #T_3ea93_row9_col4, #T_3ea93_row9_col5, #T_3ea93_row9_col6, #T_3ea93_row9_col7, #T_3ea93_row10_col0, #T_3ea93_row10_col1, #T_3ea93_row10_col2, #T_3ea93_row10_col3, #T_3ea93_row10_col4, #T_3ea93_row10_col5, #T_3ea93_row10_col6, #T_3ea93_row10_col7, #T_3ea93_row11_col0, #T_3ea93_row11_col1, #T_3ea93_row11_col2, #T_3ea93_row11_col3, #T_3ea93_row11_col4, #T_3ea93_row11_col5, #T_3ea93_row11_col6, #T_3ea93_row11_col7, #T_3ea93_row12_col0, #T_3ea93_row12_col1, #T_3ea93_row12_col2, #T_3ea93_row12_col3, #T_3ea93_row12_col4, #T_3ea93_row12_col5, #T_3ea93_row12_col6, #T_3ea93_row12_col7, #T_3ea93_row13_col0, #T_3ea93_row13_col1, #T_3ea93_row13_col2, #T_3ea93_row13_col3, #T_3ea93_row13_col4, #T_3ea93_row13_col5, #T_3ea93_row13_col6, #T_3ea93_row13_col7 {
#   text-align: left;
# }
# #T_3ea93_row0_col1, #T_3ea93_row0_col2, #T_3ea93_row0_col4, #T_3ea93_row0_col5, #T_3ea93_row0_col6, #T_3ea93_row0_col7, #T_3ea93_row7_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3ea93_row0_col8, #T_3ea93_row1_col8, #T_3ea93_row2_col8, #T_3ea93_row3_col8, #T_3ea93_row4_col8, #T_3ea93_row5_col8, #T_3ea93_row7_col8, #T_3ea93_row8_col8, #T_3ea93_row9_col8, #T_3ea93_row10_col8, #T_3ea93_row11_col8, #T_3ea93_row12_col8, #T_3ea93_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3ea93_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3ea93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ea93_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3ea93_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3ea93_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3ea93_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3ea93_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3ea93_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3ea93_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3ea93_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3ea93_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ea93_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_3ea93_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_3ea93_row0_col1" class="data row0 col1" >0.8071</td>
#       <td id="T_3ea93_row0_col2" class="data row0 col2" >0.8429</td>
#       <td id="T_3ea93_row0_col3" class="data row0 col3" >0.7029</td>
#       <td id="T_3ea93_row0_col4" class="data row0 col4" >0.7988</td>
#       <td id="T_3ea93_row0_col5" class="data row0 col5" >0.7358</td>
#       <td id="T_3ea93_row0_col6" class="data row0 col6" >0.5870</td>
#       <td id="T_3ea93_row0_col7" class="data row0 col7" >0.5995</td>
#       <td id="T_3ea93_row0_col8" class="data row0 col8" >0.6570</td>
#     </tr>
#     <tr>
#       <th id="T_3ea93_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_

# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=6745, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
finalize_model(best)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Variable1', 'Variable2',
#                                              'Variable3', 'Variable6',
#                                              'Variable7', 'Variable9'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecated'))),
#                 ('categorical...
#                                                               handle_unknown='value',
#                                                               hierarchy=None,
#                                                               min_samples_leaf=20,
#                                                               return_df=True,
#                                                               smoothing=10,
#                                                               verbose=0))),
#                 ('actual_estimator',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=6745,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d0f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d0f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3d0f6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3d0f6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3d0f6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3d0f6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3d0f6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3d0f6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3d0f6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d0f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d0f6_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_3d0f6_row0_col1" class="data row0 col1" >0.8056</td>
#       <td id="T_3d0f6_row0_col2" class="data row0 col2" >0.8482</td>
#       <td id="T_3d0f6_row0_col3" class="data row0 col3" >0.6479</td>
#       <td id="T_3d0f6_row0_col4" class="data row0 col4" >0.8214</td>
#       <td id="T_3d0f6_row0_col5" class="data row0 col5" >0.7244</td>
#       <td id="T_3d0f6_row0_col6" class="data row0 col6" >0.5774</td>
#       <td id="T_3d0f6_row0_col7" class="data row0 col7" >0.5871</td>
#     </tr>
#   </tbody>
# </table>
#      Variable1  Variable2  Variable3 Variable4 Variable5  Variable6  \
# 8     2.003191       45.0          3     8.05       blue   9.746507
# 393   2.624232       38.0          2    13.00      green   6.698955
# 121   2.671070       34.0          2    10.50      green   5.928063
# 333   2.000021       18.0          2    13.00      green   4.094314
# 438   2.399578       45.0          1    83.48       blue   4.782118
# ..         ...        ...        ...       ...       ...        ...
# 203   2.816070       16.0          3     8.05       blue   4.470352
# 131   2.020062       19.0          2    26.00      green   5.638029
# 55    2.677156       22.0          3     7.25       blue   8.768087
# 358   2.000722       58.0          1    29.70       blue   6.245989
# 327   2.046453       34.0          3     8.71       blue   1.018272
#
#      Variable7 Variable8  Variable9  TargetVariable  prediction_label  \
# 8            0    square          0               1                 0
# 393          0    square          0               0                 1
# 121          0     round          0               1                 1
# 333          0  triangle          2               1                 1
# 438          1    square          0               0                 0
# ..         ...       ...        ...             ...               ...
# 203          0  triangle          0               0                 0
# 131          0  triangle          0               1                 1
# 55           0  triangle          0               0                 0
# 358          0     round          0               0                 0
# 327          0     round          0               0                 0
#
#      prediction_score
# 8              0.9474
# 393            0.7830
# 121            0.7263
# 333            0.8710
# 438            0.6799
# ..                ...
# 203            0.8746
# 131            0.8881
# 55             0.8842
# 358            0.8309
# 327            0.8776
#
# [180 rows x 12 columns]

# %%
save_model('lr', 'lr_model_v1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Variable1', 'Variable2',
#                                               'Variable3', 'Variable6',
#                                               'Variable7', 'Variable9'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical...
#                                                                handle_unknown='value',
#                                                                return_df=True,
#                                                                use_cat_names=True,
#                                                                verbose=0))),
#                  ('rest_encoding',
#                   TransformerWrapper(exclude=None, include=['Variable4'],
#                                      transformer=TargetEncoder(cols=['Variable4'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('trained_model', 'lr')],
#           verbose=False),
#  'lr_model_v1.pkl')
